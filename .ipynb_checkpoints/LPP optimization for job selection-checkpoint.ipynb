# %% [markdown]
# ### Importing libraries :

# %%
import pandas as pd
import numpy as np
import warnings 

warnings.filterwarnings("ignore")

# %%
from pulp import *

# %% [markdown]
# ### Importing the csv files created:

# %%
user_scores =  pd.read_csv("Job_scoring_users.csv")
user_preferences = pd.read_csv("user_preferences.csv")

# %%
user_preferences
# Out:
#    Candidate  Panchkula  Ambala  Faridabad  Gurgaon  Panipat
# 0          A          1       2          5        4        3
# 1          B          2       1          5        4        3
# 2          C          2       3          1        5        4
# 3          D          2       3          5        1        4
# 4          E          1       2          5        4        3
# 5          F          1       1          4        3        4
# 6          G          2       3          5        4        1
# 7          H          2       1          5        4        3
# 8          I          1       2          5        4        3
# 9          J          1       2          5        4        3
# 10         K          1       2          5        4        3
# 11         L          2       3          1        5        4
# 12         M          2       3          5        1        4
# 13         N          1       2          5        4        3
# 14         O          1       2          5        4        3
# 15         P          1       2          5        4        3

# %% [markdown]
# ### Deciding the scoring method:

# %%
users = list(user_scores.Candidate.values)
jobs = list( user_scores.columns[1:user_scores.shape[1]].values)
user_scores_array = user_scores.iloc[:,range(1,user_scores.shape[1])].values

# %%
print( "  Maximum user score is : " ,user_scores_array.max())
# Out:
#   Maximum user score is :  8

# %% [markdown]
# The maximum score provided for scoring the user (without considering the user preferences) is 58
#
# If we build our user preferences, scoring such that the difference between any 2 levels is more than this maximum score, it'll ensure that user preferences are of foremost priority in job matching. That is, even if a user is scored very low then other location user will not be selected

# %%
max_score = 10

# %%
user_preferences = user_preferences.replace({
    1:5 * max_score, 
    2:4 * max_score,
    3:3 * max_score,
    4:2 * max_score,
    5:1 * max_score})
user_preferences_num_cols =  user_preferences.iloc[:,range(1,user_scores.shape[1])]

# %%
user_preferences_num_cols
# Out:
#     Panchkula  Ambala  Faridabad  Gurgaon  Panipat
# 0          50      40         10       20       30
# 1          40      50         10       20       30
# 2          40      30         50       10       20
# 3          40      30         10       50       20
# 4          50      40         10       20       30
# 5          50      50         20       30       20
# 6          40      30         10       20       50
# 7          40      50         10       20       30
# 8          50      40         10       20       30
# 9          50      40         10       20       30
# 10         50      40         10       20       30
# 11         40      30         50       10       20
# 12         40      30         10       50       20
# 13         50      40         10       20       30
# 14         50      40         10       20       30
# 15         50      40         10       20       30

# %%
#user_preferences = user_preferences.replace({1:1,2:0.1,3:0.01,4:0.001,5:0.0001})*10000
#user_preferences_num_cols =  user_preferences.iloc[:,range(1,user_scores.shape[1])]

# %%
user_preferences_0_array =  user_preferences_num_cols.values

# %% [markdown]
# ### Decision variable:

# %%
prob = LpProblem("Matching Jobs", LpMaximize)
y = LpVariable.dicts("pair", [(i,j)  for i in range(len(users)) for j in range(len(jobs)) ] ,cat='Binary')

# %% [markdown]
# ### Maximization problem :

# %%
prob += lpSum([ (user_preferences_0_array[i][j] + user_scores_array[i][j]) * y[(i,j)] for i in range(len(users)) for j in range(len(jobs)) ])

# %% [markdown]
# ### Contraints:

# %%
## each person should be given only one job 

for i in range(len(users)):
    prob += lpSum(y[(i,j)] for j in range(len(jobs))) <= 1

## place constraints: 
for j in [0]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 4
                  
for j in [1]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 2     
                  
for j in [2]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 2     
                  
for j in [3]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 2     

for j in [4]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 3     
    
prob.solve()
# Out:
# 1

# %% [markdown]
# ### Creating a record of all the score values :

# %%
scores_array = user_preferences_0_array.copy()
scores_array[:,:] = 0

for i in range(len(users)):
    for j in range(len(jobs)):
        scores_array[i,j] = (user_preferences_0_array[i][j] + user_scores_array[i][j] )

# %% [markdown]
# ## Presenting results with the cells highlighted

# %% [markdown]
# ##### Creating array of matched values:

# %%
matches_array =  user_preferences_0_array.copy()
matches_array[:,:] = 0

for i in range(len(users)):
    for j in range(len(jobs)):
        matches_array[i,j] =  y[(i,j)].varValue 
        
matches_df =  pd.DataFrame(matches_array, columns =  user_scores.columns[range(1,user_scores.shape[1] )] )
matches_df['Candidate'] = user_scores["Candidate"]
matches_df =matches_df[user_scores.columns]
matches_df
# Out:
#    Candidate  Panchkula  Ambala  Faridabad  Gurgaon  Panipat
# 0          A          0       0          0        0        0
# 1          B          0       1          0        0        0
# 2          C          0       0          1        0        0
# 3          D          0       0          0        1        0
# 4          E          1       0          0        0        0
# 5          F          0       0          0        0        0
# 6          G          0       0          0        0        1
# 7          H          0       1          0        0        0
# 8          I          0       0          0        0        1
# 9          J          0       0          0        0        0
# 10         K          1       0          0        0        0
# 11         L          0       0          1        0        0
# 12         M          0       0          0        1        0
# 13         N          0       0          0        0        1
# 14         O          1       0          0        0        0
# 15         P          1       0          0        0        0

# %% [markdown]
# ### Combining users preferences and scores :

# %%
results_df =  user_scores.copy()
for colnames  in results_df.columns[range(1,len(results_df.columns))]:
    results_df[colnames] = user_scores[colnames].astype('str') + "," + user_preferences[colnames].astype('str')

# %% [markdown]
# ### Results with coloured tiles :

# %%
style_df = (
        matches_df == 1                  # Compare DataFrames
).replace({
    True: 'background-color:yellow',  # True Styles
    False: ''                      # False Styles
})

results_df =  results_df.style.apply(lambda _: style_df, axis=None)
results_df
# Out:
# <style type="text/css">
# #T_8bd08_row1_col2, #T_8bd08_row2_col3, #T_8bd08_row3_col4, #T_8bd08_row4_col1, #T_8bd08_row6_col5, #T_8bd08_row7_col2, #T_8bd08_row8_col5, #T_8bd08_row10_col1, #T_8bd08_row11_col3, #T_8bd08_row12_col4, #T_8bd08_row13_col5, #T_8bd08_row14_col1, #T_8bd08_row15_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8bd08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bd08_level0_col0" class="col_heading level0 col0" >Candidate</th>
#       <th id="T_8bd08_level0_col1" class="col_heading level0 col1" >Panchkula</th>
#       <th id="T_8bd08_level0_col2" class="col_heading level0 col2" >Ambala</th>
#       <th id="T_8bd08_level0_col3" class="col_heading level0 col3" >Faridabad</th>
#       <th id="T_8bd08_level0_col4" class="col_heading level0 col4" >Gurgaon</th>
#       <th id="T_8bd08_level0_col5" class="col_heading level0 col5" >Panipat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bd08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bd08_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_8bd08_row0_col1" class="data row0 col1" >2,50</td>
#       <td id="T_8bd08_row0_col2" class="data row0 col2" >2,40</td>
#       <td id="T_8bd08_row0_col3" class="data row0 col3" >2,10</td>
#       <td id="T_8bd08_row0_col4" class="data row0 col4" >2,20</td>
#       <td id="T_8bd08_row0_col5" class="data row0 col5" >2,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8bd08_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_8bd08_row1_col1" class="data row1 col1" >4,40</td>
#       <td id="T_8bd08_row1_col2" class="data row1 col2" >4,50</td>
#       <td id="T_8bd08_row1_col3" class="data row1 col3" >4,10</td>
#       <td id="T_8bd08_row1_col4" class="data row1 col4" >4,20</td>
#       <td id="T_8bd08_row1_col5" class="data row1 col5" >4,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8bd08_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_8bd08_row2_col1" class="data row2 col1" >5,40</td>
#       <td id="T_8bd08_row2_col2" class="data row2 col2" >5,30</td>
#       <td id="T_8bd08_row2_col3" class="data row2 col3" >5,50</td>
#       <td id="T_8bd08_row2_col4" class="data row2 col4" >5,10</td>
#       <td id="T_8bd08_row2_col5" class="data row2 col5" >5,20</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8bd08_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_8bd08_row3_col1" class="data row3 col1" >2,40</td>
#       <td id="T_8bd08_row3_col2" class="data row3 col2" >2,30</td>
#       <td id="T_8bd08_row3_col3" class="data row3 col3" >2,10</td>
#       <td id="T_8bd08_row3_col4" class="data row3 col4" >2,50</td>
#       <td id="T_8bd08_row3_col5" class="data row3 col5" >2,20</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8bd08_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_8bd08_row4_col1" class="data row4 col1" >6,50</td>
#       <td id="T_8bd08_row4_col2" class="data row4 col2" >6,40</td>
#       <td id="T_8bd08_row4_col3" class="data row4 col3" >6,10</td>
#       <td id="T_8bd08_row4_col4" class="data row4 col4" >6,20</td>
#       <td id="T_8bd08_row4_col5" class="data row4 col5" >6,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8bd08_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_8bd08_row5_col1" class="data row5 col1" >2,50</td>
#       <td id="T_8bd08_row5_col2" class="data row5 col2" >2,50</td>
#       <td id="T_8bd08_row5_col3" class="data row5 col3" >2,20</td>
#       <td id="T_8bd08_row5_col4" class="data row5 col4" >2,30</td>
#       <td id="T_8bd08_row5_col5" class="data row5 col5" >2,20</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8bd08_row6_col0" class="data row6 col0" >G</td>
#       <td id="T_8bd08_row6_col1" class="data row6 col1" >4,40</td>
#       <td id="T_8bd08_row6_col2" class="data row6 col2" >4,30</td>
#       <td id="T_8bd08_row6_col3" class="data row6 col3" >4,10</td>
#       <td id="T_8bd08_row6_col4" class="data row6 col4" >4,20</td>
#       <td id="T_8bd08_row6_col5" class="data row6 col5" >4,50</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8bd08_row7_col0" class="data row7 col0" >H</td>
#       <td id="T_8bd08_row7_col1" class="data row7 col1" >8,40</td>
#       <td id="T_8bd08_row7_col2" class="data row7 col2" >8,50</td>
#       <td id="T_8bd08_row7_col3" class="data row7 col3" >8,10</td>
#       <td id="T_8bd08_row7_col4" class="data row7 col4" >8,20</td>
#       <td id="T_8bd08_row7_col5" class="data row7 col5" >8,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8bd08_row8_col0" class="data row8 col0" >I</td>
#       <td id="T_8bd08_row8_col1" class="data row8 col1" >4,50</td>
#       <td id="T_8bd08_row8_col2" class="data row8 col2" >4,40</td>
#       <td id="T_8bd08_row8_col3" class="data row8 col3" >4,10</td>
#       <td id="T_8bd08_row8_col4" class="data row8 col4" >4,20</td>
#       <td id="T_8bd08_row8_col5" class="data row8 col5" >4,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8bd08_row9_col0" class="data row9 col0" >J</td>
#       <td id="T_8bd08_row9_col1" class="data row9 col1" >3,50</td>
#       <td id="T_8bd08_row9_col2" class="data row9 col2" >3,40</td>
#       <td id="T_8bd08_row9_col3" class="data row9 col3" >3,10</td>
#       <td id="T_8bd08_row9_col4" class="data row9 col4" >3,20</td>
#       <td id="T_8bd08_row9_col5" class="data row9 col5" >3,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8bd08_row10_col0" class="data row10 col0" >K</td>
#       <td id="T_8bd08_row10_col1" class="data row10 col1" >5,50</td>
#       <td id="T_8bd08_row10_col2" class="data row10 col2" >5,40</td>
#       <td id="T_8bd08_row10_col3" class="data row10 col3" >5,10</td>
#       <td id="T_8bd08_row10_col4" class="data row10 col4" >5,20</td>
#       <td id="T_8bd08_row10_col5" class="data row10 col5" >5,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8bd08_row11_col0" class="data row11 col0" >L</td>
#       <td id="T_8bd08_row11_col1" class="data row11 col1" >7,40</td>
#       <td id="T_8bd08_row11_col2" class="data row11 col2" >7,30</td>
#       <td id="T_8bd08_row11_col3" class="data row11 col3" >7,50</td>
#       <td id="T_8bd08_row11_col4" class="data row11 col4" >7,10</td>
#       <td id="T_8bd08_row11_col5" class="data row11 col5" >7,20</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8bd08_row12_col0" class="data row12 col0" >M</td>
#       <td id="T_8bd08_row12_col1" class="data row12 col1" >2,40</td>
#       <td id="T_8bd08_row12_col2" class="data row12 col2" >2,30</td>
#       <td id="T_8bd08_row12_col3" class="data row12 col3" >2,10</td>
#       <td id="T_8bd08_row12_col4" class="data row12 col4" >2,50</td>
#       <td id="T_8bd08_row12_col5" class="data row12 col5" >2,20</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8bd08_row13_col0" class="data row13 col0" >N</td>
#       <td id="T_8bd08_row13_col1" class="data row13 col1" >4,50</td>
#       <td id="T_8bd08_row13_col2" class="data row13 col2" >4,40</td>
#       <td id="T_8bd08_row13_col3" class="data row13 col3" >4,10</td>
#       <td id="T_8bd08_row13_col4" class="data row13 col4" >4,20</td>
#       <td id="T_8bd08_row13_col5" class="data row13 col5" >4,30</td>
#     </tr>
#     <tr>
#       <th id="T_8bd08_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T

# %% [markdown]
# ### Caste constraints :

# %% [markdown]
# Introducing A, F, J  as SC:

# %%
user_SC_index =  [0,5,9]

# %% [markdown]
# Setting 2 as number of SC required :

# %%
SC_required =  2

# %% [markdown]
# ### Decision variable:

# %%
prob = LpProblem("Matching Jobs", LpMaximize)
y = LpVariable.dicts("pair", [(i,j)  for i in range(len(users)) for j in range(len(jobs)) ] ,cat='Binary')

# %% [markdown]
# ### Maximization problem :

# %%
prob += lpSum([ (user_preferences_0_array[i][j] + user_scores_array[i][j]) * y[(i,j)] for i in range(len(users)) for j in range(len(jobs)) ])

# %% [markdown]
# ### Contraints:

# %%
## each person should be given only one job 

for i in range(len(users)):
    prob += lpSum(y[(i,j)] for j in range(len(jobs))) <= 1

## place constraints: 
for j in [0]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 4
                  
for j in [1]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 2     
                  
for j in [2]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 2     
                  
for j in [3]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 2     

for j in [4]:
    prob += lpSum(y[(i,j)] for i in range(len(users))) == 3    
    
    
## SC constraints: 

prob += lpSum([  y[(i,j)] for i in user_SC_index for j in range(len(jobs))  ]) == SC_required
    
    
prob.solve()
# Out:
# 1

# %%
matches_array =  user_preferences_0_array.copy()
matches_array[:,:] = 0

for i in range(len(users)):
    for j in range(len(jobs)):
        matches_array[i,j] =  y[(i,j)].varValue 
        
matches_df =  pd.DataFrame(matches_array, columns =  user_scores.columns[range(1,user_scores.shape[1] )] )
matches_df['Candidate'] = user_scores["Candidate"]
matches_df =matches_df[user_scores.columns]
matches_df

results_df =  user_scores.copy()
for colnames  in results_df.columns[range(1,len(results_df.columns))]:
    results_df[colnames] = user_scores[colnames].astype('str') + "," + user_preferences[colnames].astype('str')

    
style_df = (
        matches_df == 1                  # Compare DataFrames
).replace({
    True: 'background-color:yellow',  # True Styles
    False: ''                      # False Styles
})    
    

results_df =  results_df.style.apply(lambda _: style_df, axis=None)
results_df
# Out:
# <style type="text/css">
# #T_46ef7_row0_col5, #T_46ef7_row1_col2, #T_46ef7_row2_col3, #T_46ef7_row3_col4, #T_46ef7_row4_col1, #T_46ef7_row6_col5, #T_46ef7_row7_col2, #T_46ef7_row9_col1, #T_46ef7_row10_col5, #T_46ef7_row11_col3, #T_46ef7_row12_col4, #T_46ef7_row14_col1, #T_46ef7_row15_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_46ef7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46ef7_level0_col0" class="col_heading level0 col0" >Candidate</th>
#       <th id="T_46ef7_level0_col1" class="col_heading level0 col1" >Panchkula</th>
#       <th id="T_46ef7_level0_col2" class="col_heading level0 col2" >Ambala</th>
#       <th id="T_46ef7_level0_col3" class="col_heading level0 col3" >Faridabad</th>
#       <th id="T_46ef7_level0_col4" class="col_heading level0 col4" >Gurgaon</th>
#       <th id="T_46ef7_level0_col5" class="col_heading level0 col5" >Panipat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46ef7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46ef7_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_46ef7_row0_col1" class="data row0 col1" >2,50</td>
#       <td id="T_46ef7_row0_col2" class="data row0 col2" >2,40</td>
#       <td id="T_46ef7_row0_col3" class="data row0 col3" >2,10</td>
#       <td id="T_46ef7_row0_col4" class="data row0 col4" >2,20</td>
#       <td id="T_46ef7_row0_col5" class="data row0 col5" >2,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46ef7_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_46ef7_row1_col1" class="data row1 col1" >4,40</td>
#       <td id="T_46ef7_row1_col2" class="data row1 col2" >4,50</td>
#       <td id="T_46ef7_row1_col3" class="data row1 col3" >4,10</td>
#       <td id="T_46ef7_row1_col4" class="data row1 col4" >4,20</td>
#       <td id="T_46ef7_row1_col5" class="data row1 col5" >4,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46ef7_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_46ef7_row2_col1" class="data row2 col1" >5,40</td>
#       <td id="T_46ef7_row2_col2" class="data row2 col2" >5,30</td>
#       <td id="T_46ef7_row2_col3" class="data row2 col3" >5,50</td>
#       <td id="T_46ef7_row2_col4" class="data row2 col4" >5,10</td>
#       <td id="T_46ef7_row2_col5" class="data row2 col5" >5,20</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46ef7_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_46ef7_row3_col1" class="data row3 col1" >2,40</td>
#       <td id="T_46ef7_row3_col2" class="data row3 col2" >2,30</td>
#       <td id="T_46ef7_row3_col3" class="data row3 col3" >2,10</td>
#       <td id="T_46ef7_row3_col4" class="data row3 col4" >2,50</td>
#       <td id="T_46ef7_row3_col5" class="data row3 col5" >2,20</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46ef7_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_46ef7_row4_col1" class="data row4 col1" >6,50</td>
#       <td id="T_46ef7_row4_col2" class="data row4 col2" >6,40</td>
#       <td id="T_46ef7_row4_col3" class="data row4 col3" >6,10</td>
#       <td id="T_46ef7_row4_col4" class="data row4 col4" >6,20</td>
#       <td id="T_46ef7_row4_col5" class="data row4 col5" >6,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46ef7_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_46ef7_row5_col1" class="data row5 col1" >2,50</td>
#       <td id="T_46ef7_row5_col2" class="data row5 col2" >2,50</td>
#       <td id="T_46ef7_row5_col3" class="data row5 col3" >2,20</td>
#       <td id="T_46ef7_row5_col4" class="data row5 col4" >2,30</td>
#       <td id="T_46ef7_row5_col5" class="data row5 col5" >2,20</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_46ef7_row6_col0" class="data row6 col0" >G</td>
#       <td id="T_46ef7_row6_col1" class="data row6 col1" >4,40</td>
#       <td id="T_46ef7_row6_col2" class="data row6 col2" >4,30</td>
#       <td id="T_46ef7_row6_col3" class="data row6 col3" >4,10</td>
#       <td id="T_46ef7_row6_col4" class="data row6 col4" >4,20</td>
#       <td id="T_46ef7_row6_col5" class="data row6 col5" >4,50</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_46ef7_row7_col0" class="data row7 col0" >H</td>
#       <td id="T_46ef7_row7_col1" class="data row7 col1" >8,40</td>
#       <td id="T_46ef7_row7_col2" class="data row7 col2" >8,50</td>
#       <td id="T_46ef7_row7_col3" class="data row7 col3" >8,10</td>
#       <td id="T_46ef7_row7_col4" class="data row7 col4" >8,20</td>
#       <td id="T_46ef7_row7_col5" class="data row7 col5" >8,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_46ef7_row8_col0" class="data row8 col0" >I</td>
#       <td id="T_46ef7_row8_col1" class="data row8 col1" >4,50</td>
#       <td id="T_46ef7_row8_col2" class="data row8 col2" >4,40</td>
#       <td id="T_46ef7_row8_col3" class="data row8 col3" >4,10</td>
#       <td id="T_46ef7_row8_col4" class="data row8 col4" >4,20</td>
#       <td id="T_46ef7_row8_col5" class="data row8 col5" >4,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_46ef7_row9_col0" class="data row9 col0" >J</td>
#       <td id="T_46ef7_row9_col1" class="data row9 col1" >3,50</td>
#       <td id="T_46ef7_row9_col2" class="data row9 col2" >3,40</td>
#       <td id="T_46ef7_row9_col3" class="data row9 col3" >3,10</td>
#       <td id="T_46ef7_row9_col4" class="data row9 col4" >3,20</td>
#       <td id="T_46ef7_row9_col5" class="data row9 col5" >3,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_46ef7_row10_col0" class="data row10 col0" >K</td>
#       <td id="T_46ef7_row10_col1" class="data row10 col1" >5,50</td>
#       <td id="T_46ef7_row10_col2" class="data row10 col2" >5,40</td>
#       <td id="T_46ef7_row10_col3" class="data row10 col3" >5,10</td>
#       <td id="T_46ef7_row10_col4" class="data row10 col4" >5,20</td>
#       <td id="T_46ef7_row10_col5" class="data row10 col5" >5,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_46ef7_row11_col0" class="data row11 col0" >L</td>
#       <td id="T_46ef7_row11_col1" class="data row11 col1" >7,40</td>
#       <td id="T_46ef7_row11_col2" class="data row11 col2" >7,30</td>
#       <td id="T_46ef7_row11_col3" class="data row11 col3" >7,50</td>
#       <td id="T_46ef7_row11_col4" class="data row11 col4" >7,10</td>
#       <td id="T_46ef7_row11_col5" class="data row11 col5" >7,20</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_46ef7_row12_col0" class="data row12 col0" >M</td>
#       <td id="T_46ef7_row12_col1" class="data row12 col1" >2,40</td>
#       <td id="T_46ef7_row12_col2" class="data row12 col2" >2,30</td>
#       <td id="T_46ef7_row12_col3" class="data row12 col3" >2,10</td>
#       <td id="T_46ef7_row12_col4" class="data row12 col4" >2,50</td>
#       <td id="T_46ef7_row12_col5" class="data row12 col5" >2,20</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_46ef7_row13_col0" class="data row13 col0" >N</td>
#       <td id="T_46ef7_row13_col1" class="data row13 col1" >4,50</td>
#       <td id="T_46ef7_row13_col2" class="data row13 col2" >4,40</td>
#       <td id="T_46ef7_row13_col3" class="data row13 col3" >4,10</td>
#       <td id="T_46ef7_row13_col4" class="data row13 col4" >4,20</td>
#       <td id="T_46ef7_row13_col5" class="data row13 col5" >4,30</td>
#     </tr>
#     <tr>
#       <th id="T_46ef7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_
